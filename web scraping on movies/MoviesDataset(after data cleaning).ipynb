# %%
import numpy as np
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.imdb.com/list/ls098063263/?sort=list_order,asc&st_dt=&mode=detail&page=1 '

# %%
page = requests.get(url)

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text)

# %%
title = []
for t in soup.find_all('h3',class_ = 'lister-item-header'):
    text = t.text
    regex_title = re.findall('\d+\.\s([a-zA-Z0-9].+)',text)
    if regex_title:
        title.append(regex_title[0])
    else:
        title.append(np.nan)

# %%
len(title)
# Out:
# 100

# %%
year = []
for y in soup.find_all('h3',class_ = 'lister-item-header'):
    text = y.text
    regex_year = re.findall('\((\d+)\)',text)
    if regex_year:
        year.append(regex_year[0])
    else:
        year.append(np.nan)

# %%
len(year)
# Out:
# 100

# %%
certificate = []
for c in soup.find_all('div',class_ = 'lister-item mode-detail'):
    cer = c.find('span',class_ = 'certificate')
    if cer:
        certificate.append(cer.text)
    else:
        certificate.append(np.nan)

# %%
len(certificate)
# Out:
# 100

# %%
runtime = []
for r in soup.find_all('div',class_ = 'lister-item mode-detail'):
    time = r.find('span',class_ = 'runtime')
    if time:
        runtime.append(time.text)
    else:
        runtime.append(np.nan)

# %%
len(runtime)
# Out:
# 100

# %%
genre = []
for g in soup.find_all('div',class_ = 'lister-item mode-detail'):
    gen = g.find('span',class_ = 'genre').text
    regex_genre = re.findall('\w+',gen)
    if regex_genre:
        genre.append(regex_genre[0])
    else:
        genre.append(np.nan)

# %%
len(genre)
# Out:
# 100

# %%
rating = []
for ra in soup.find_all('div',class_ = 'lister-item mode-detail'):
    rate = ra.find('span',class_ = 'ipl-rating-star__rating')
    if rate:
        rating.append(rate.text)
    else:
        rating.append(np.nan)

# %%
len(rating)
# Out:
# 100

# %%
metascore = []
for m in soup.find_all('div',class_ = 'lister-item mode-detail'):
    meta = m.find('div',class_ = 'inline-block ratings-metascore')
    if meta:
        regex_meta = re.findall('\d+',meta.text)
        metascore.append(regex_meta[0])
    else:
        metascore.append(np.nan)

# %%
len(metascore)
# Out:
# 100

# %%
soup.find('div',class_ = 'lister-item mode-detail').text
# Out:
# '\n\n \n \n\n\n1.\nAvatar\n(2009)\n\n\nUA\n|\n162 min\n|\n\nAction, Adventure, Fantasy            \n\n\n\n\n\n\n\n\n\n\n7.9\n\n\n\n\n\n\n\n\n\n\n\n\n0\n\n\n\n\n\n\n\n\nRate\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n1\n\n\n\n\n\n\n\n\nRate\n\n\n\n\n\n\n\n\n\n\n\n2\n\n\n\n\n\n\n\n\nRate\n\n\n\n\n\n\n\n\n\n\n\n3\n\n\n\n\n\n\n\n\nRate\n\n\n\n\n\n\n\n\n\n\n\n4\n\n\n\n\n\n\n\n\nRate\n\n\n\n\n\n\n\n\n\n\n\n5\n\n\n\n\n\n\n\n\nRate\n\n\n\n\n\n\n\n\n\n\n\n6\n\n\n\n\n\n\n\n\nRate\n\n\n\n\n\n\n\n\n\n\n\n7\n\n\n\n\n\n\n\n\nRate\n\n\n\n\n\n\n\n\n\n\n\n8\n\n\n\n\n\n\n\n\nRate\n\n\n\n\n\n\n\n\n\n\n\n9\n\n\n\n\n\n\n\n\nRate\n\n\n\n\n\n\n\n\n\n\n\n10\n\n\n\n\n\n\n\n\nRate\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n0\n\n\nError: please try again.\n\n\n\n\n\n\n\n\n83        \n        Metascore\n        \n\nA paraplegic Marine dispatched to the moon Pandora on a unique mission becomes torn between following his orders and protecting the world he feels is his home.\n\n    Director:\nJames Cameron\n| \n    Stars:\nS
# ...

# %%
director = []
for d in soup.find_all('div',class_ = 'lister-item mode-detail'):
    dire = d.text
    regex_dire = re.findall('tors?:\n(.+)',dire)
    if regex_dire:
        director.append(regex_dire[0])
    else:
        director.append(np.nan)

# %%
len(director)
# Out:
# 100

# %%
stars = []
for s in soup.find_all('div',class_ = 'lister-item mode-detail'):
    st = s.text
    regex_st = re.findall('tars:\n(.+)\n',st)
    if regex_st:
        stars.append(regex_st[0])
    else:
        stars.append(np.nan)

# %%
len(stars)
# Out:
# 100

# %%
votes = []
for v in soup.find_all('div',class_ = 'lister-item mode-detail'):
    vote = v.text
    regex_vote = re.findall('Votes:\n(.+)\n',vote)
    if regex_vote:
        votes.append(regex_vote[0])
    else:
        votes.append(np.nan)

# %%
len(votes)
# Out:
# 100

# %%
gross = []
for g in soup.find_all('div',class_ = 'lister-item mode-detail'):
    gr = g.text
    regex_gr = re.findall('e Gross:\s\$(.+)',gr)
    if regex_gr:
        gross.append(regex_gr[0])
    else:
        gross.append(np.nan)

# %%
len(gross)
# Out:
# 100

# %%
dic = {'Title':title,
      'Release_year':year,
      'Certificate':certificate,
      'Rating':rating,
      'Runtime(min)':runtime,
      'Genre':genre,
      'Metascore':metascore,
      'Director':director,
      'Stars':stars,
      'Votes':votes,
      'Gross($)':gross}

# %%
df = pd.DataFrame(dic)

# %%
df
# Out:
#                                          Title Release_year Certificate  \
# 0                                       Avatar         2009          UA
# 1                            Avengers: Endgame         2019          UA
# 2                     Avatar: The Way of Water         2022          UA
# 3                                      Titanic         1997          UA
# 4   Star Wars: Episode VII - The Force Awakens         2015           U
# ..                                         ...          ...         ...
# 95                                        Coco         2017           U
# 96     Fantastic Beasts and Where to Find Them         2016          UA
# 97                             Shrek the Third         2007           U
# 98                     Jumanji: The Next Level         2019          UA
# 99    Harry Potter and the Prisoner of Azkaban         2004           U
#
#    Rating Runtime(min)      Genre Metascore         Director  \
# ...

# %%
df.to_csv('MoviesDataset_page_1.csv',index = None)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Imdb_movies.csv")
df.head(5)
# Out:
#    Unnamed: 0                                       Title  Release_year  \
# 0           0                                      Avatar          2009
# 1           1                           Avengers: Endgame          2019
# 2           2                    Avatar: The Way of Water          2022
# 3           3                                     Titanic          1997
# 4           4  Star Wars: Episode VII - The Force Awakens          2015
#
#   Certificate  Rating Runtime(min)   Genre  Metascore         Director  \
# 0          UA     7.9      162 min  Action       83.0    James Cameron
# 1          UA     8.4      181 min  Action       78.0  Anthony Russo,
# 2          UA     7.6      192 min  Action       67.0    James Cameron
# 3          UA     7.9      194 min   Drama       75.0    James Cameron
# 4           U     7.8      138 min  Action       80.0      J.J. Abrams
#
#                  Stars      Votes        Gross($)
# 0    Sam Worthington,   13,58,528  2,92,37,06,026
# ...

# %%
df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
df.head(5)
# Out:
#                                         Title  Release_year Certificate  \
# 0                                      Avatar          2009          UA
# 1                           Avengers: Endgame          2019          UA
# 2                    Avatar: The Way of Water          2022          UA
# 3                                     Titanic          1997          UA
# 4  Star Wars: Episode VII - The Force Awakens          2015           U
#
#    Rating Runtime(min)   Genre  Metascore         Director  \
# 0     7.9      162 min  Action       83.0    James Cameron
# 1     8.4      181 min  Action       78.0  Anthony Russo,
# 2     7.6      192 min  Action       67.0    James Cameron
# 3     7.9      194 min   Drama       75.0    James Cameron
# 4     7.8      138 min  Action       80.0      J.J. Abrams
#
#                  Stars      Votes        Gross($)
# 0    Sam Worthington,   13,58,528  2,92,37,06,026
# 1  Robert Downey Jr.,   12,08,382  2,79,94,39,100
# ...

# %%
df.isnull().sum()
# Out:
# Title            0
# Release_year     0
# Certificate     50
# Rating           0
# Runtime(min)     0
# Genre            0
# Metascore       38
# Director         0
# Stars            0
# Votes            0
# Gross($)         0
# dtype: int64

# %%
df.dropna(how="any",axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Title           0
# Release_year    0
# Certificate     0
# Rating          0
# Runtime(min)    0
# Genre           0
# Metascore       0
# Director        0
# Stars           0
# Votes           0
# Gross($)        0
# dtype: int64

# %%
df.dtypes
# Out:
# Title            object
# Release_year      int64
# Certificate      object
# Rating          float64
# Runtime(min)     object
# Genre            object
# Metascore       float64
# Director         object
# Stars            object
# Votes            object
# Gross($)         object
# dtype: object

# %%
# Convert Votes and Gross into integers
df.Votes=df.Votes.replace(",","",regex=True).astype("int")

# %%
df.Votes.dtype
# Out:
# dtype('int32')

# %%
df["Gross($)"]=df["Gross($)"].replace(",","",regex=True).astype("int64")

# %%
df["Gross($)"].dtype
# Out:
# dtype('int64')

# %%
# Covert Runtime from object to integer
df["Runtime(min)"]=df["Runtime(min)"].replace("min","",regex=True).astype("int")

# %%
df["Runtime(min)"].dtype
# Out:
# dtype('int32')

# %%
df.dtypes
# Out:
# Title            object
# Release_year      int64
# Certificate      object
# Rating          float64
# Runtime(min)      int32
# Genre            object
# Metascore       float64
# Director         object
# Stars            object
# Votes             int32
# Gross($)          int64
# dtype: object

# %%
# find duplicate values if exist.
df.loc[df.duplicated(keep="first"),:] #There is no duplicated values.
# Out:
# Empty DataFrame
# Columns: [Title, Release_year, Certificate, Rating, Runtime(min), Genre, Metascore, Director, Stars, Votes, Gross($)]
# Index: []

# %%
df.Release_year.unique()
# Out:
# array([2009, 2019, 2022, 1997, 2015, 2018, 2021, 2012, 2011, 2023, 2017,
#        2013, 2016, 2003, 1993, 2014, 2010, 2006, 1999, 2001, 2008, 1994,
#        2007, 2002, 2004, 2005, 1996, 1982, 1977, 1998, 2000, 1980, 1991,
#        1990, 1992, 1975, 1983, 1989, 2020, 1973, 1939, 1978, 1995, 1981,
#        1985, 1986, 1988, 1984, 1987, 1942, 1972, 1961, 1979, 1967, 1937],
#       dtype=int64)

# %%
df.Certificate.unique()
# Out:
# array(['UA', 'U', 'A', '12+', 'U/A', 'R', '(Banned)', '16', '15+', '7',
#        'PG', '18', '13', 'PG-13', 'UA 16+', 'G', 'Not Rated'],
#       dtype=object)

# %%
df.Rating.unique()
# Out:
# array([7.9, 8.4, 7.6, 7.8, 8.2, 6.9, 6.8, 8. , 7.1, 8.3, 7.3, 8.1, 6.1,
#        7.4, 6.6, 6.4, 9. , 6.2, 5.6, 6.5, 7.7, 8.5, 8.8, 7.5, 6.3, 6.7,
#        5.5, 5.9, 7. , 7.2, 5.8, 8.6, 8.7, 5.2, 4.9, 4.8, 5.1, 4.2, 5.4,
#        4.5, 5.7, 6. , 5.3, 4.6, 4.3, 5. , 4. , 9.2, 3.8, 3.4, 8.9])

# %%
df.Genre.unique()
# Out:
# array(['Action', 'Drama', 'Animation', 'Adventure', 'Crime', 'Biography',
#        'Mystery', 'Horror', 'Comedy', 'Documentary', 'Fantasy'],
#       dtype=object)

# %%
df.Metascore.unique()
# Out:
# array([ 83.,  78.,  67.,  75.,  80.,  68.,  71.,  59.,  55.,  69.,  64.,
#         66.,  88.,  85.,  46.,  84.,  51.,  65.,  56.,  62.,  94.,  81.,
#         42.,  32.,  53.,  92.,  45.,  49.,  77.,  58.,  38.,  50.,  60.,
#         87.,  90.,  63.,  61.,  73.,  44.,  74.,  76.,  35.,  52.,  82.,
#         39.,  86.,  72.,  57.,  96.,  40.,  70.,  79.,  54.,  47.,  27.,
#         48.,  30.,  41.,  95.,  43.,  31.,  91.,  34.,  97.,  33.,  24.,
#         26.,  20.,  28.,  37.,  89., 100.,  19.,  36.,  23.,  21.,  12.,
#         25.])

# %%
df["Runtime(min)"].unique()
# Out:
# array([162, 181, 192, 194, 138, 149, 148, 124, 118, 143, 137, 130, 103,
#        141, 134,  92, 152, 128, 102, 129, 136,  91, 147, 201, 123, 154,
#        127, 165, 164, 122, 100, 151, 133,  89,  97, 108, 169, 119, 146,
#         98,  88, 106, 144, 161, 126, 179,  87, 153,  93, 178, 157, 139,
#         94, 140,  95, 112, 115, 150, 121, 145, 105, 132, 142, 158, 163,
#        176, 104,  96, 117, 135, 131, 107,  90, 120, 111, 116, 101, 125,
#        187,  86, 156, 113,  85, 155, 114, 110, 183, 109,  84, 180, 238,
#         81,  82,  83, 166, 195,  99, 159, 189,  69, 175,  79, 170,  78,
#         80, 167,  72], dtype=int64)

# %%
df
# Out:
#                                           Title  Release_year Certificate  \
# 0                                        Avatar          2009          UA
# 1                             Avengers: Endgame          2019          UA
# 2                      Avatar: The Way of Water          2022          UA
# 3                                       Titanic          1997          UA
# 4    Star Wars: Episode VII - The Force Awakens          2015           U
# ..                                          ...           ...         ...
# 994                                   Allegiant          2016          13
# 995                                   Daredevil          2003          UA
# 997                 He's Just Not That Into You          2009          13
# 998                                   Eagle Eye          2008           A
# 999                            Along Came Polly          2004          UA
#
#      Rating  Runtime(min)   Genre  Metascore             Director  \
# ...

# %%
d1=df.groupby("Genre")[["Gross($)"]].sum()
d1
# Out:
#                  Gross($)
# Genre
# Action       204316819482
# Adventure     38065652358
# Animation     75645693351
# Biography      9237474351
# Comedy        33371382465
# Crime          7572340340
# Documentary     483630470
# Drama         24334715311
# Fantasy         409459843
# Horror         6062657648
# Mystery        1276115830

# %%
d1=df.groupby("Genre")[["Runtime(min)"]].sum()
d1
# Out:
#              Runtime(min)
# Genre
# Action              53084
# Adventure            9801
# Animation           15159
# Biography            4319
# Comedy              13009
# Crime                3346
# Documentary           233
# Drama                9191
# Fantasy               241
# Horror               2340
# Mystery               414

# %%
d1=df.groupby(["Release_year","Genre"])[["Gross($)"]].sum()
d1
# Out:
#                           Gross($)
# Release_year Genre
# 1937         Animation   184925486
# 1939         Drama       402382193
# 1942         Animation   267447150
# 1961         Animation   215880014
# 1967         Animation   205843612
# ...                            ...
# 2022         Horror      396958863
# 2023         Action     3204760422
#              Adventure   507224677
#              Animation  1912327808
#              Drama       275248615
#
# [248 rows x 1 columns]

# %% [markdown]
# ## Univariate Analysis

# %%
#categorical

# %%
# how many movies were released in a year wise
no_movies = df.Release_year.value_counts()

# %%
plt.figure(figsize=(20,5))
df.Release_year.value_counts().plot.bar()
plt.xlabel("Released Year")
plt.ylabel("No.of movies")
plt.show()

# %%
df1=df["Release_year"].value_counts()
df2=df1.reset_index()
df2.rename(columns={"index":"Release_year","Release_year":"No_count"},inplace=True)
df2.sort_values("Release_year",inplace=True)
df2.head(2)
# Out:
#     Release_year  No_count
# 54          1937         1
# 43          1939         1

# %%
df2=df.groupby("Release_year")[["Gross($)"]].mean()
df2=df2.reset_index()
df2.head(2)
# Out:
#    Release_year     Gross($)
# 0          1937  184925486.0
# 1          1939  402382193.0

# %%
plt.figure(figsize=(20,5))
sns.lineplot(x="Release_year", y="Gross($)",data=df2,marker="*",markersize=15,linewidth=2)
plt.show()

# %%
sns.countplot(x="Certificate",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
df2=df.groupby("Release_year")[["Gross($)"]].sum()
df2=df2.reset_index()
plt.figure(figsize=(20,5))
sns.lineplot(x="Release_year", y="Gross($)",data=df2,marker="*",markersize=15,linewidth=2)
plt.show()

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Categorical

# %%
plt.figure(figsize=(20,5))
plt.xlabel("Release_year")
plt.ylabel("No.of movies")
x=np.arange(len(df2.Release_year))
plt.xticks(x,df2.Release_year,rotation=90)
plt.bar(x,df2.No_count)
plt.show()

# %%
sns.countplot(x="Certificate",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
df.Genre.value_counts().plot.pie(radius=3,autopct="%1.2f%%",label="",explode=[0,0,0,0,0,0,0,0,0.50,0.100,0.140])

# %% [markdown]
# ## Numeric

# %%
plt.xlabel("Rating")
plt.ylabel("No.of Movies")
plt.title("HISTOGRAM OF RATINGS")
plt.hist(df.Rating,bins=[3,5,7,9,10])
plt.show()

# %%
sns.displot(df.Metascore,kde=True,bins=[10,30,50,70,90,100])
plt.show()
#pavan kde plot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-6a83ffbefa3f> in <module>
# ----> 1 sns.displot(df.Metascore,kde=True,bins=[10,30,50,70,90,100])
#       2 plt.show()
#       3 #pavan kde plot
#
# AttributeError: module 'seaborn' has no attribute 'displot'

# %% [markdown]
# # Bivariate

# %% [markdown]
# ### Cat Vs Cat

# %%
df.head(1)
# Out:
#     Title  Release_year Certificate  Rating  Runtime(min)   Genre  Metascore  \
# 0  Avatar          2009          UA     7.9           162  Action       83.0
#
#         Director              Stars    Votes    Gross($)
# 0  James Cameron  Sam Worthington,   1358528  2923706026

# %%
plt.figure(figsize=(20,5))
plt.title("COUNT PLOT OF RELEASE YEAR & GENRE")
sns.countplot(x ='Release_year', hue = "Genre", data = df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Cat Vs Num

# %%
plt.figure(figsize=(20,5))
sns.lineplot(x="Release_year", y="Gross($)",data=df2,marker="*",markersize=15,linewidth=2)
plt.xlabel("Release_year")
plt.ylabel("Gross($)")
plt.title("Line plot of Gross amount")
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.title("OUTLIERS OF VARIOUS GENRES")
sns.boxplot(data=df,x="Genre",y="Gross($)")
plt.show()

# %%
df2=df.groupby("Genre")[["Votes"]].mean()
df2=df2.reset_index()
df2
# Out:
#           Genre          Votes
# 0        Action  421851.728337
# 1     Adventure  348304.086420
# 2     Animation  263541.784810
# 3     Biography  516043.250000
# 4        Comedy  265262.308333
# 5         Crime  729526.400000
# 6   Documentary   86279.500000
# 7         Drama  432085.380282
# 8       Fantasy  325954.500000
# 9        Horror  280987.363636
# 10      Mystery  627165.666667

# %%
plt.pie(df2.Votes,labels=df2.Genre,autopct="%1.2f%%",radius=2)

plt.show()

# %% [markdown]
# ### Num Vs Num

# %%
plt.figure(figsize=(10,5))
plt.title("SCATTER PLOT FOR VOTES & RUNTIME")
sns.scatterplot(x=df["Runtime(min)"],y=df.Votes)
plt.show()

# %%
sns.pairplot(data=df,vars=["Metascore","Gross($)"])
plt.title("PAIR PLOT FOR METASCORE & GROSS")
plt.show()

# %%
sns.jointplot(x="Rating", y="Metascore", data=df)
#plt.title("JOINT PLOT FOR RATING METASCORE")
plt.show()

# %%
df.head(2)
# Out:
#                Title  Release_year Certificate  Rating  Runtime(min)   Genre  \
# 0             Avatar          2009          UA     7.9           162  Action
# 1  Avengers: Endgame          2019          UA     8.4           181  Action
#
#    Metascore         Director                Stars    Votes    Gross($)
# 0       83.0    James Cameron    Sam Worthington,   1358528  2923706026
# 1       78.0  Anthony Russo,   Robert Downey Jr.,   1208382  2799439100

# %% [markdown]
# ## Multivariate Analysis

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True)
plt.show() # pavan

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x="Gross($)", y="Votes",
             hue="Genre", 
             data=df)
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.scatterplot(x="Gross($)",y="Rating",hue="Genre",data=df)
plt.show()

# %%
#df.Genre.value_counts().plot.pie(radius=3,autopct="%1.2f%%",label="",explode=[0,0,0,0,0,0,0,0,0.50,0.100,0.140])

# %%
df1=df1.reset_index()
df1.rename(columns={"index":"Genre","Genre":"No_count"},inplace=True)
df1
# Out:
#           Genre  No_count
# 0        Action       427
# 1     Animation       158
# 2        Comedy       120
# 3     Adventure        81
# 4         Drama        71
# 5     Biography        32
# 6         Crime        25
# 7        Horror        22
# 8       Mystery         3
# 9   Documentary         2
# 10      Fantasy         2

# %%
df.head(2)
# Out:
#                Title  Release_year Certificate  Rating  Runtime(min)   Genre  \
# 0             Avatar          2009          UA     7.9           162  Action
# 1  Avengers: Endgame          2019          UA     8.4           181  Action
#
#    Metascore         Director                Stars    Votes    Gross($)
# 0       83.0    James Cameron    Sam Worthington,   1358528  2923706026
# 1       78.0  Anthony Russo,   Robert Downey Jr.,   1208382  2799439100

# %%
print(df.Rating.min())
print(df.Rating.max())
# Out:
# 3.4
# 9.2

# %%
plt.figure(figsize=(13,5))
plt.subplot(3,3,1)
plt.xlabel("Rating")
plt.ylabel("No.of Movies")
plt.hist(df.Rating,bins=[3,5,7,9,10])
plt.title("Histogram of Movie's Rating")
#plt.show()
plt.subplot(3,3,3)
sns.lineplot(x="Release_year", y="Gross($)",data=df2,marker="*",markersize=15,linewidth=2)
plt.xlabel("Release_year")
plt.ylabel("Gross($)")
plt.title("Line plot of Gross amount")
#plt.show()
plt.subplot(3,3,7)
df.Genre.value_counts().plot.pie(radius=2,autopct="%1.2f%%",label="",explode=[0,0,0,0,0,0,0,0,0.50,0.100,0.140])
#plt.title("Pie Chart Movies released in Genre wise")
#plt.show()
plt.subplot(3,3,9)
df.Genre.value_counts().plot.bar()
plt.xlabel("Genre")
plt.ylabel("No.of movies")
plt.title("Bar Chart of Movies in Genre wise")
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
df.head(2)
# Out:
#                Title  Release_year Certificate  Rating  Runtime(min)   Genre  \
# 0             Avatar          2009          UA     7.9           162  Action
# 1  Avengers: Endgame          2019          UA     8.4           181  Action
#
#    Metascore         Director                Stars    Votes    Gross($)
# 0       83.0    James Cameron    Sam Worthington,   1358528  2923706026
# 1       78.0  Anthony Russo,   Robert Downey Jr.,   1208382  2799439100

# %%
# Cat Vs Num
df3=df.groupby("Genre")[["Rating"]].mean()
df3=df3.reset_index()
df3.head(1)
# Out:
#     Genre   Rating
# 0  Action  6.72904

# %%
for i in range(len(df3.Rating)):
    df3.Rating[i]=np.round(df3.Rating[i],2)
    #a=np.round(i,2)
    #i=a
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df3
# Out:
#           Genre  Rating
# 0        Action    6.73
# 1     Adventure    6.79
# 2     Animation    6.93
# 3     Biography    7.69
# 4        Comedy    6.57
# 5         Crime    7.61
# 6   Documentary    7.35
# 7         Drama    7.26
# 8       Fantasy    7.10
# 9        Horror    6.60
# 10      Mystery    7.23

# %%
plt.xlabel("Genre")
plt.ylabel("Rating")
x=np.arange(len(df3.Genre))
plt.xticks(x,df3.Genre,rotation=90)
plt.bar(x,df3.Rating)
plt.show()

# %%
sns.lineplot(x="Release_year", y="Gross($)",data=df2,marker="*",markersize=15,linewidth=2)
plt.xlabel("Release_year")
plt.ylabel("Gross($)")
plt.title("Line plot of Gross amount")
plt.show()
